# %%
from google.colab import drive
import os

if os.path.exists('/content/gdrive')==False:
  drive.mount('/content/gdrive')
  print('Google Drive is mounted\n')
else:
  print('Google Drive is already mounted\n')
# Out:
# Google Drive is already mounted

# %%
import numpy as np

# 랜덤시드 고정시키기
np.random.seed(777)

from keras.preprocessing.image import ImageDataGenerator

# 데이터셋 불러오기
train_datagen = ImageDataGenerator(rescale=1./255
                                  ) 


train_generator = train_datagen.flow_from_directory(
        '/content/gdrive/My Drive/Colab Notebooks/house/handwriting_shape/train',
        target_size=(24, 24),
        batch_size=3,
        class_mode='categorical') # trian data

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/gdrive/My Drive/Colab Notebooks/house/handwriting_shape/test',
        target_size=(24, 24),    
        batch_size=3,
        class_mode='categorical') #test data
   
from keras.models import Sequential, Model
from keras import layers
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Input, BatchNormalization, AveragePooling2D
from keras.optimizers import SGD
from keras.layers import Dropout
from keras.applications import ResNet50
classes = 5
filter_size = 16  # 필터 개수
kernel_size = (3,3) # 필터 사이즈
pool_size = (2,2)
input_shape = (24,24,3)
def getModel(input_shape):
  classes = 5
  filter_size = 16  # 필터 개수
  kernel_size = (3,3) # 필터 사이즈
  pool_size = (2,2)
  m = Sequential()
  
  def identity_block(input_tensor, kernel_size, filters, stage, block):
    filters1, filters2, filters3 = filters
    
    conv_name_base = 'res' + str(stage) + block +  '_branch'
    bn_name_base = 'bn' + str(stage) + block +  '_branch'
    
    x = Conv2D(filters1, (1,1), name = conv_name_base +'2a')(input_tensor)
    x = BatchNormalization(name = bn_name_base+'2a')(x)
    x = Activation('relu')(x)

    x = Conv2D(filters2, kernel_size,padding='same',name = conv_name_base+'2b')(x)
    x = BatchNormalization(name = bn_name_base +'2b')(x)
    x = Activation('relu')(x)
    
    
    x = Conv2D(filters3,(1,1),name = conv_name_base+'2c')(x)
    x = BatchNormalization(name = bn_name_base +'2c')(x)
    
    x = layers.add([x,input_tensor])
    x = Activation('relu')(x)
    
    return x
  
  def conv_block(input_tensor,kernel_size, filters,stage, block,strides=(2,2)):
    filters1, filters2 , filters3 = filters
    conv_name_base = 'res' + str(stage)+block+'_branch'
    bn_name_base = 'bn' +str(stage) +block+'_branch'
    
    x = Conv2D(filters1, (1,1),strides = strides, name = conv_name_base +'2a')(input_tensor)
    x = BatchNormalization(name = bn_name_base +'2a')(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters2, kernel_size,padding = 'same', name = conv_name_base +'2b')(x)
    x = BatchNormalization(name = bn_name_base+'2b')(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters3,(1,1), name = conv_name_base +'2c')(x)
    x = BatchNormalization(name = bn_name_base+'2c')(x)
    
    shortcut = Conv2D(filters3, (1,1), strides = strides, name = conv_name_base+'1')(input_tensor)
    shortcut = BatchNormalization(name = bn_name_base+'1')(shortcut)
    
    x = layers.add([x,shortcut])
    x = Activation('relu')(x)
    
    return x
  
  i = Input(shape = input_shape)
  x = Conv2D(64, (7,7),strides = (2,2), padding = 'same', name = 'conv1')(i)
  x = BatchNormalization(name = 'bn_conv1')(x)
  x = Activation('relu')(x)
  x = MaxPooling2D((3,3), strides =(2,2))(x)
  
  x = conv_block(x,3,[64,64,256],stage = 2 , block = 'a', strides =(1,1))
  x = identity_block(x,3,[64,64,256], stage = 2, block = 'b')
  x = identity_block(x,3,[64,64,256], stage = 2, block = 'c')
  x = conv_block(x,3,[128,128,512], stage = 3, block = 'a')
  x = identity_block(x,3,[128,128,512], stage = 3, block = 'b')
  x = identity_block(x,3,[128,128,512], stage = 3, block = 'c')
  x = identity_block(x,3,[128,128,512], stage = 3, block = 'd')
  
  x = AveragePooling2D((2,2), name = 'avg_pool')(x)
  
  x = Flatten()(x)
  x = Dense(classes,activation = "softmax", name = "softmax")(x)
  
  
  return Model(i,x, name = 'Resnet')


    
    
    







m = getModel(input_shape)



m.summary() #모델에 대한 정보 출력

  

# 모델 엮기
m.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 학습시키기
m.fit_generator(
        train_generator,
        steps_per_epoch=15 * 100,
        epochs=50,
       )

# 모델 평가하기
print("-- Evaluate --")

scores = m.evaluate_generator(
            test_generator, 
            steps = 5)

print("%s: %.2f%%" %(m.metrics_names[1], scores[1]*100))


# 모델 예측하기
print("-- Predict --")

output = m.predict_generator(
            test_generator, 
            steps = 5)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})

print(output)
# Out:
# Found 2180 images belonging to 5 classes.
# Found 210 images belonging to 5 classes.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 24, 24, 3)    0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 12, 12, 64)   9472        input_6[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 12, 12, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 12, 12, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 5, 5, 64)     0           activation_63[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 5, 5, 64)     4160        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 5, 5, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 5, 5, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 5, 5, 64)     36928       activation_64[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 5, 5, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 5, 5, 64)     0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 5, 5, 256)    16640       activation_65[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 5, 5, 256)    16640       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 5, 5, 256)    1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 5, 5, 256)    1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 5, 5, 256)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 5, 5, 256)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 5, 5, 64)     16448       activation_66[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 5, 5, 64)     256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 5, 5, 64)     0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 5, 5, 64)     36928       activation_67[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 5, 5, 64)     256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 5, 5, 64)     0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 5, 5, 256)    16640       activation_68[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 5, 5, 256)    1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 5, 5, 256)    0           bn2b_branch2c[0][0]
#                                                                  activation_66[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 5, 5, 256)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 5, 5, 64)     16448       activation_69[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 5, 5, 64)     256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 5, 5, 64)     0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 5, 5, 64)     36928       activation_70[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 5, 5, 64)     256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 5, 5, 64)     0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 5, 5, 256)    16640       activation_71[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 5, 5, 256)    1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 5, 5, 256)    0           bn2c_branch2c[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 5, 5, 256)    0           add_21[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 3, 3, 128)    32896       activation_72[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 3, 3, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 3, 3, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 3, 3, 128)    147584      activation_73[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 3, 3, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 3, 3, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 3, 3, 512)    66048       activation_74[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 3, 3, 512)    131584      activation_72[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 3, 3, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 3, 3, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 3, 3, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 3, 3, 128)    65664       activation_75[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 3, 3, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 3, 3, 128)    147584      activation_76[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 3, 3, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 3, 3, 512)    66048       activation_77[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 3, 3, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 3, 3, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 512)    0           add_23[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 3, 3, 128)    65664       activation_78[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 3, 3, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 3, 3, 128)    147584      activation_79[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 3, 3, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 3, 3, 512)    66048       activation_80[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 3, 3, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 3, 3, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_78[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 512)    0           add_24[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 3, 3, 128)    65664       activation_81[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 3, 3, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 3, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 3, 3, 128)    147584      activation_82[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 3, 3, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 3, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 3, 3, 512)    66048       activation_83[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 3, 3, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 3, 3, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_81[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 3, 512)    0           add_25[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 512)    0           activation_84[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 512)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# softmax (Dense)                 (None, 5)            2565        flatten_3[0][0]
# ==================================================================================================
# Total params: 1,462,661
# Trainable params: 1,452,549
# Non-trainable params: 10,112
# __________________________________________________________________________________________________
# Epoch 1/50
# 1500/1500 [==============================] - 126s 84ms/step - loss: 1.5020 - acc: 0.4638
# Epoch 2/50
# 1500/1500 [==============================] - 121s 81ms/step - loss: 1.0529 - acc: 0.5928
# Epoch 3/50
# 1500/1500 [==============================] - 121s 81ms/step - loss: 0.9057 - acc: 0.6619
# Epoch 4/50
# 1500/1500 [==============================] - 122s 81ms/step - loss: 0.7672 - acc: 0.7094
# Epoch 5/50
# 1500/1500 [==============================] - 122s 81ms/step - loss: 0.6332 - acc: 0.7666
# Epoch 6/50
# 1500/1500 [==============================] - 122s 82ms/step - loss: 0.5131 - acc: 0.8119
# Epoch 7/50
# 1500/1500 [==============================] - 122s 81ms/step - loss: 0.4093 - acc: 0.8482
# Epoch 8/50
# 1500/1500 [==============================] - 122s 81ms/step - loss: 0.3099 - acc: 0.8887
# Epoch 9/50
# 1500/1500 [==============================] - 122s 82ms/step - loss: 0.2530 - acc: 0.9094
# Epoch 10/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.2261 - acc: 0.9242
# Epoch 11/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1867 - acc: 0.9358
# Epoch 12/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1580 - acc: 0.9472
# Epoch 13/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1584 - acc: 0.9460
# Epoch 14/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1114 - acc: 0.9627
# Epoch 15/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1385 - acc: 0.9519
# Epoch 16/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1289 - acc: 0.9583
# Epoch 17/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.1011 - acc: 0.9671
# Epoch 18/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0934 - acc: 0.9678
# Epoch 19/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0994 - acc: 0.9678
# Epoch 20/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0744 - acc: 0.9751
# Epoch 21/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0861 - acc: 0.9700
# Epoch 22/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0717 - acc: 0.9760
# Epoch 23/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0704 - acc: 0.9780
# Epoch 24/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0805 - acc: 0.9709
# Epoch 25/50
# 1500/1500 [==============================] - 123s 82ms/step - loss: 0.0516 - acc: 0.9829
# Epoch 26/50
# 1500/1500 [==============================] - 129s 86ms/step - loss: 0.0892 - acc: 0.9718
# Epoch 27/50
# 1500/1500 [==============================] - 126s 84ms/step - loss: 0.0534 - acc: 0.9796
# Epoch 28/50
# 1500/1500 [==============================] - 127s 85ms/step - loss: 0.0620 - acc: 0.9811
# Epoch 29/50
# 1500/1500 [==============================] - 127s 84ms/step - loss: 0.0513 - acc: 0.9813
# Epoch 30/50
# 1500/1500 [==============================] - 127s 85ms/step - loss: 0.0651 - acc: 0.9767
# Epoch 31/50
# 1500/1500 [==============================] - 127s 85ms/step - loss: 0.0487 - acc: 0.9836
# Epoch 32/50
# 1500/1500 [==============================] - 127s 84ms/step - loss: 0.0563 - acc: 0.9818
# Epoch 33/50
# 1500/1500 [==============================] - 127s 84ms/step - loss: 0.0440 - acc: 0.9871
# Epoch 34/50
# 1500/1500 [==============================] - 126s 84ms/step - loss: 0.0533 - acc: 0.9831
# Epoch 35/50
# 1500/1500 [==============================] - 126s 84ms/step - loss: 0.0359 - acc: 0.9871
# Epoch 36/50
# 1500/1500 [==============================] - 125s 83ms/step - loss: 0.0574 - acc: 0.9807
# Epoch 37/50
# 1500/1500 [==============================] - 125s 83ms/step - loss: 0.0441 - acc: 0.9856
# Epoch 38/50
# 1500/1500 [==============================] - 126s 84ms/step - loss: 0.0458 - acc: 0.9858
# Epoch 39/50
# 1500/1500 [==============================] - 125s 83ms/step - loss: 0.0403 - acc: 0.9861
# Epoch 40/50
#  524/1500 [=========>....................] - ETA: 1:21 - loss: 0.0240 - acc: 0.9936Buffered data was truncated after reaching the output size limit.
